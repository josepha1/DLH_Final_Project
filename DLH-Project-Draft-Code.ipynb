# %% [markdown]
# # Contextual Embeddings from Clinical Notes Improves Prediction of Sepsis

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import torch
import numpy as np
import re
import tqdm
from sklearn.metrics import roc_auc_score, f1_score
from torch import tensor
from torch.nn import Softmax
from transformers import AutoTokenizer, AutoModel
from torch.nn import LSTM

# %%
def preprocess(x):
    y = re.sub('\\[(.*?)\\]', '', x)  # remove de-identified brackets
    y = re.sub('[0-9]+\.', '', y)  # remove 1.2. since the segmenter segments based on this
    y = re.sub('dr\.', 'doctor', y)
    y = re.sub('m\.d\.', 'md', y)
    y = re.sub('admission date:', '', y)
    y = re.sub('discharge date:', '', y)
    y = re.sub('--|__|==', '', y)
    return y

# %%
def preprocessing(df_less_n):
    df_less_n['TEXT'] = df_less_n['TEXT'].fillna(' ')
    df_less_n['TEXT'] = df_less_n['TEXT'].str.replace('\n', ' ')
    df_less_n['TEXT'] = df_less_n['TEXT'].str.replace('\r', ' ')
    df_less_n['TEXT'] = df_less_n['TEXT'].apply(str.strip)
    df_less_n['TEXT'] = df_less_n['TEXT'].str.lower()

    df_less_n['TEXT'] = df_less_n['TEXT'].apply(lambda x: preprocess(x))
    
    chunk_size = 140

    # to get 512 words chunks for sepsis tasks
    df_len = len(df_less_n)
    want = pd.DataFrame({'ID': [], 'TEXT': [], 'Label': []})
    for i in range(df_len):
        x = df_less_n.TEXT.iloc[i].split()
        n = int(len(x) / chunk_size)
        for j in range(n):
            want = want.append({'TEXT': ' '.join(x[j * chunk_size:(j + 1) * chunk_size]), 'Label': df_less_n.SEPSIS.iloc[i],
                                'ID': df_less_n.SUBJECT_ID.iloc[i]}, ignore_index=True)
        if len(x) % chunk_size > 10:
            want = want.append({'TEXT': ' '.join(x[-(len(x) % chunk_size):]), 'Label': df_less_n.SEPSIS.iloc[i],
                                'ID': df_less_n.HADM_IDleft.iloc[i]}, ignore_index=True)

    return want

# %%
clinical_notes = pd.read_csv('NOTEEVENTS.csv')
diagnoses_icd = pd.read_csv('DIAGNOSES_ICD.csv')
diagnoses_icd['SEPSIS'] = diagnoses_icd['ICD9_CODE'].apply(lambda x: True if x == '99591' else False) 
diagnoses_icd[diagnoses_icd.ICD9_CODE == '99591']
# Out:
# C:\Users\josep\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE  SEPSIS
# 276        505          64   172056      3.0     99591    True
# 450        679          85   112077     18.0     99591    True
# 1084       477          61   189535      8.0     99591    True
# 1097       490          62   116009      4.0     99591    True
# 1825      2383         191   136614      4.0     99591    True
# ...        ...         ...      ...      ...       ...     ...
# 647075  632154       95895   160501     10.0     99591    True
# 647523  633127       96145   137544      3.0     99591    True
# 648242  638716       97229   191765      7.0     99591    True
# 650106  640418       97598   148929     11.0     99591    True
# 650934  638442       97158   152158      6.0     99591    True
#
# [1272 rows x 6 columns]

# %%
clinical_notes_mod = clinical_notes.join(diagnoses_icd, lsuffix = 'left', rsuffix = 'right', on = 'SUBJECT_ID', how = 'inner')

# %%
new_clinical_notes = clinical_notes_mod[['SUBJECT_ID', 'HADM_IDleft', 'ROW_IDleft', 'ROW_IDright', 'CATEGORY', 'DESCRIPTION', 'TEXT',
                                        'SEPSIS', 'ICD9_CODE']]
text = new_clinical_notes.TEXT
new_clinical_notes[0:10]
# Out:
#         SUBJECT_ID  HADM_IDleft  ROW_IDleft  ROW_IDright           CATEGORY  \
# 0            22532     167853.0         174        38127  Discharge summary
# 245          22532     167853.0         170        38127  Discharge summary
# 60246        22532     167853.0       59795        38127               Echo
# 60247        22532     167853.0       59796        38127               Echo
# 102792       22532     167853.0      106289        38127                ECG
# 102793       22532     167853.0      106290        38127                ECG
# 102974       22532     167853.0      106291        38127                ECG
# 102975       22532     167853.0      106292        38127                ECG
# 756685       22532     167853.0      763295        38127          Radiology
# 758388       22532     167853.0      764802        38127          Radiology
#
#                   DESCRIPTION  \
# 0                      Report
# 245                    Report
# 60246                  Report
# 60247                  Report
# 102792                 Report
# 102793                 Report
# 102974                 Report
# 102975                 Report
# 756685    CHEST (PORTABLE AP)
# 758388  CT ABDOMEN W/CONTRAST
#
#                                                      TEXT  SEPSIS ICD9_CODE
# 0       Admission Date:  [**2151-7-16**]       Dischar...   False      5559
# 245     Admission Date:  [**2151-7-16**]       Dischar...   False      5559
# 60246   PATIENT/TEST INFORMATION:\nIndication: Aortic ...   False      5559
# 60247   PATIENT/TEST INFORMATION:\nIndication: Endocar...   False      5559
# 102792  Atrial fibrillation with a slow ventricular re...   False      5559
# 102793  Atrial fibrillation with a slow ventricular re...   False      5559
# 102974  Atrial fibrillation with a slow ventricular re...   False      5559
# 102975  Atrial fibrillation with a rapid ventricular r...   False      5559
# 756685  [**2151-7-16**] 5:01 AM\n CHEST (PORTABLE AP) ...   False      5559
# 758388  [**2151-8-4**] 3:39 PM\n CT ABDOMEN W/CONTRAST...   False      5559

# %%
df_sample = new_clinical_notes.sample(n = 100, random_state = 3)
df_sample
# Out:
#          SUBJECT_ID  HADM_IDleft  ROW_IDleft  ROW_IDright       CATEGORY  \
# 1257842       70393     111964.0     1253154        94121      Radiology
# 782159         6863          NaN      785956         5931      Radiology
# 1595258       27736     196052.0     1625137        19955  Nursing/other
# 2067539       26547     162368.0     2040091        31431  Nursing/other
# 1294190        2710     152429.0     1297631         1399  Nursing/other
# ...             ...          ...         ...          ...            ...
# 1505211       18463     128430.0     1505125        31972  Nursing/other
# 423213        76529     178352.0      422050        61841        Nursing
# 971771         6990     115527.0      964281         6058      Radiology
# 1009283       22954     120339.0     1031289        34504      Radiology
# 1916947       15204     168396.0     1891903        13031  Nursing/other
#
#                                DESCRIPTION  \
# 1257842                CHEST (PORTABLE AP)
# 782159           L TIB/FIB (AP & LAT) LEFT
# 1595258                             Report
# 2067539                             Report
# 1294190                             Report
# ...                                    ...
# 1505211                             Report
# 423213               Nursing Progress Note
# 971771   RP FEMORAL VASCULAR US RIGHT PORT
# 1009283                   PORTABLE ABDOMEN
# 1916947                             Report
#
#                                                       TEXT  SEPSIS ICD9_CODE
# 1257842  [**2172-9-30**] 3:48 AM\n CHEST (PORTABLE AP) ...   False     42832
# 782159   [**2170-2-17**] 9:54 PM\n TIB/FIB (AP & LAT) L...   False      4019
# 1595258  CVICU NPN\nO: ROS\n\nPt was taken to the or at...   False      2851
# 2067539  NPN 1500-2300 con't\n\n\n#6 CVR O: Infant note...    True     99591
# 1294190  NURSING UPDATE\nCV:\n   AFEBRILE. PA CATH IN S...   False     40301
# ...                                                    ...     ...       ...
# 1505211  Pt on AC 17 x 550 + 8, 50%. Ph is being partia...   False      7318
# 423213   HPI: 88F s/p AVR, CABG [**10-12**], readmit wi...   False      2182
# 971771   [**2128-7-8**] 9:42 AM\n FEMORAL VASCULAR US R...   False     34590
# 1009283  [**2137-7-21**] 8:46 AM\n PORTABLE ABDOMEN    ...   False     V1046
# 1916947  npn 7p-7a\n\n\n(see nursing flowsheet)\n\n#2  ...   False      9975
#
# [100 rows x 9 columns]

# %%
(df_sample[df_sample.SEPSIS == True])
# Out:
#          SUBJECT_ID  HADM_IDleft  ROW_IDleft  ROW_IDright       CATEGORY  \
# 2067539       26547     162368.0     2040091        31431  Nursing/other
#
#         DESCRIPTION                                               TEXT  \
# 2067539      Report  NPN 1500-2300 con't\n\n\n#6 CVR O: Infant note...
#
#          SEPSIS ICD9_CODE
# 2067539    True     99591

# %%
tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
conf = model.config
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tensor_list = []
for j in range(89):
    output = []
    print(f'The value of j is: {j}')
    text_df = preprocessing(df_sample[j:j + 1])
    for i in range(len(text_df.TEXT)):
        print(f'*******ANALYZING TEXT*******')
        encoding = tokenizer(text_df.TEXT[i], return_tensors = 'pt')
        bert_output = model(**encoding)
        last_hidden_state = bert_output['last_hidden_state']
        print(f'The value of last_hidden_state is: {last_hidden_state}')
        output.append(last_hidden_state)
        print(f'The value of output is: {output}')
    out_tensor = torch.cat(output, dim = 1)
    out_tensor_mean = out_tensor.mean()
    print(f'The value of out_tensor_mean is: {out_tensor_mean}')
    tensor_list.append(out_tensor_mean)
new_tensor = torch.as_tensor(tensor_list)
# Out:
# The value of j is: 0
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 2.8309e-01, -1.9076e-01, -1.5633e-01,  ..., -1.9615e-01,
#           -9.5207e-03,  1.1701e-04],
#          [ 1.8201e-01, -3.5765e-01, -6.4796e-02,  ...,  2.6135e-01,
#            8.4063e-01,  5.3832e-01],
#          [ 4.0169e-01, -1.0161e+00, -3.8747e-01,  ...,  2.0839e-02,
#           -2.0262e-01, -4.2888e-01],
#          ...,
#          [ 5.4076e-02, -3.3269e-01,  2.1977e-01,  ..., -2.2167e-01,
#           -2.7461e-01, -2.4079e-01],
#          [ 1.8790e-01, -5.1146e-01, -9.1895e-02,  ...,  2.2198e-01,
#            1.7985e-01, -4.4622e-01],
#          [ 1.3302e+00, -6.9869e-01, -2.4012e-01,  ...,  1.1947e-02,
#           -9.9954e-02,  3.4472e-01]]], grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 2.8309e-01, -1.9076e-01, -1.5633e-01,  ..., -1.9615e-01,
#           -9.5207e-03,  1.1701e-04],
#          [ 1.8201e-01, -3.5765e-01, -6.4796e-02,  ...,  2.6135e-01,
#            8.4063e-01,  5.3832e-01],
#          [ 4.0169e-01, -1.0161e+00, -3.8747e-01,  ...,  2.0839e-02,
#           -2.0262e-01, -4.2888e-01],
#          ...,
#          [ 5.4076e-02, -3.3269e-01,  2.1977e-01,  ..., -2.2167e-01,
#           -2.7461e-01, -2.4079e-01],
#          [ 1.8790e-01, -5.1146e-01, -9.1895e-02,  ...,  2.2198e-01,
#            1.7985e-01, -4.4622e-01],
#          [ 1.3302e+00, -6.9869e-01, -2.4012e-01,  ...,  1.1947e-02,
#           -9.9954e-02,  3.4472e-01]]], grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.0076321265660226345
# The value of j is: 1
# *******ANALYZING TEXT*******
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].fillna(' ')
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].str.replace('\n', ' ')
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].str.replace('\r', ' ')
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].apply(str.strip)
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].str.lower()
# C:\Users\josep\AppData\Local\Temp/ipykernel_22904/2775733063.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less_n['TEXT'] = df_less_n['TEXT'].apply(lambda x: preprocess(x))
# The value of last_hidden_state is: tensor([[[ 0.4914, -0.1029, -0.0829,  ..., -0.2729,  0.2178, -0.1669],
#          [ 0.0498, -0.3919,  0.3352,  ...,  0.6010,  1.0587,  0.1658],
#          [ 0.9293, -1.1858, -0.2185,  ...,  0.1179, -0.0585, -0.6884],
#          ...,
#          [ 0.5938, -0.1281,  0.6650,  ..., -0.3583,  0.3442,  0.0326],
#          [ 0.4150, -0.5352,  0.1030,  ...,  0.1867, -0.0361, -0.0912],
#          [ 1.6309, -1.2278, -0.2070,  ..., -0.1980,  0.1433,  0.1171]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.4914, -0.1029, -0.0829,  ..., -0.2729,  0.2178, -0.1669],
#          [ 0.0498, -0.3919,  0.3352,  ...,  0.6010,  1.0587,  0.1658],
#          [ 0.9293, -1.1858, -0.2185,  ...,  0.1179, -0.0585, -0.6884],
#          ...,
#          [ 0.5938, -0.1281,  0.6650,  ..., -0.3583,  0.3442,  0.0326],
#          [ 0.4150, -0.5352,  0.1030,  ...,  0.1867, -0.0361, -0.0912],
#          [ 1.6309, -1.2278, -0.2070,  ..., -0.1980,  0.1433,  0.1171]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.6105,  0.0110,  0.0903,  ..., -0.5262,  0.3706,  0.1809],
#          [ 0.3097,  0.2443, -0.2180,  ...,  0.3936,  0.0270,  0.2879],
#          [ 0.4032,  0.0606, -0.0350,  ...,  0.1166, -0.0049, -0.1184],
#          ...,
#          [ 0.1937, -1.0070,  0.3820,  ...,  0.4419, -0.3806, -0.6361],
#          [ 0.2171, -0.5115, -0.0139,  ...,  0.0153,  0.2608, -0.1373],
#          [ 1.9277, -1.0616,  0.0491,  ..., -0.7603,  0.7934,  0.7505]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.4914, -0.1029, -0.0829,  ..., -0.2729,  0.2178, -0.1669],
#          [ 0.0498, -0.3919,  0.3352,  ...,  0.6010,  1.0587,  0.1658],
#          [ 0.9293, -1.1858, -0.2185,  ...,  0.1179, -0.0585, -0.6884],
#          ...,
#          [ 0.5938, -0.1281,  0.6650,  ..., -0.3583,  0.3442,  0.0326],
#          [ 0.4150, -0.5352,  0.1030,  ...,  0.1867, -0.0361, -0.0912],
#          [ 1.6309, -1.2278, -0.2070,  ..., -0.1980,  0.1433,  0.1171]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.6105,  0.0110,  0.0903,  ..., -0.5262,  0.3706,  0.1809],
#          [ 0.3097,  0.2443, -0.2180,  ...,  0.3936,  0.0270,  0.2879],
#          [ 0.4032,  0.0606, -0.0350,  ...,  0.1166, -0.0049, -0.1184],
#          ...,
#          [ 0.1937, -1.0070,  0.3820,  ...,  0.4419, -0.3806, -0.6361],
#          [ 0.2171, -0.5115, -0.0139,  ...,  0.0153,  0.2608, -0.1373],
#          [ 1.9277, -1.0616,  0.0491,  ..., -0.7603,  0.7934,  0.7505]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007685106247663498
# The value of j is: 2
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1426,  0.2943, -0.2977,  ..., -0.0059, -0.1510,  0.2142],
#          [ 0.1418, -0.0791, -0.1137,  ...,  0.2599, -0.0053, -0.1936],
#          [ 0.4859, -0.0917,  0.1386,  ..., -0.0019, -0.4429, -0.2793],
#          ...,
#          [ 0.3083, -0.3140,  0.1484,  ...,  0.1835, -0.9105,  0.1192],
#          [ 0.2134, -0.0352,  0.1111,  ..., -0.1908, -0.2832,  0.2886],
#          [ 0.4408, -0.2555, -0.1602,  ..., -0.3808,  0.2271,  0.4936]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1426,  0.2943, -0.2977,  ..., -0.0059, -0.1510,  0.2142],
#          [ 0.1418, -0.0791, -0.1137,  ...,  0.2599, -0.0053, -0.1936],
#          [ 0.4859, -0.0917,  0.1386,  ..., -0.0019, -0.4429, -0.2793],
#          ...,
#          [ 0.3083, -0.3140,  0.1484,  ...,  0.1835, -0.9105,  0.1192],
#          [ 0.2134, -0.0352,  0.1111,  ..., -0.1908, -0.2832,  0.2886],
#          [ 0.4408, -0.2555, -0.1602,  ..., -0.3808,  0.2271,  0.4936]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0119,  0.3195, -0.4456,  ..., -0.1317,  0.0327, -0.1775],
#          [-0.0641,  0.0896, -0.3738,  ..., -0.5250,  0.2368,  0.0848],
#          [-0.3334, -0.8389,  0.1121,  ..., -0.2743,  0.7290, -0.4304],
#          ...,
#          [-0.1453,  0.1960, -0.4812,  ...,  0.1560, -0.0969, -0.0907],
#          [-0.2490, -0.3528, -0.1440,  ..., -0.3964, -0.4265, -0.0278],
#          [ 0.5205, -0.4674, -0.5675,  ..., -0.3998,  0.5997,  0.0822]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1426,  0.2943, -0.2977,  ..., -0.0059, -0.1510,  0.2142],
#          [ 0.1418, -0.0791, -0.1137,  ...,  0.2599, -0.0053, -0.1936],
#          [ 0.4859, -0.0917,  0.1386,  ..., -0.0019, -0.4429, -0.2793],
#          ...,
#          [ 0.3083, -0.3140,  0.1484,  ...,  0.1835, -0.9105,  0.1192],
#          [ 0.2134, -0.0352,  0.1111,  ..., -0.1908, -0.2832,  0.2886],
#          [ 0.4408, -0.2555, -0.1602,  ..., -0.3808,  0.2271,  0.4936]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0119,  0.3195, -0.4456,  ..., -0.1317,  0.0327, -0.1775],
#          [-0.0641,  0.0896, -0.3738,  ..., -0.5250,  0.2368,  0.0848],
#          [-0.3334, -0.8389,  0.1121,  ..., -0.2743,  0.7290, -0.4304],
#          ...,
#          [-0.1453,  0.1960, -0.4812,  ...,  0.1560, -0.0969, -0.0907],
#          [-0.2490, -0.3528, -0.1440,  ..., -0.3964, -0.4265, -0.0278],
#          [ 0.5205, -0.4674, -0.5675,  ..., -0.3998,  0.5997,  0.0822]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1243, -0.1492,  0.0763,  ..., -0.3899, -0.1230, -0.2863],
#          [-0.3438, -0.0646,  0.0673,  ...,  0.0715, -0.2095,  0.1872],
#          [-0.1614, -0.0079,  0.1361,  ...,  0.3874, -0.4111, -0.1361],
#          ...,
#          [ 0.1563, -0.1212,  0.0914,  ..., -0.5487, -0.7687, -0.0679],
#          [-0.1254, -0.6892,  0.1198,  ..., -0.0182, -0.4301, -0.2170],
#          [ 0.1536, -0.9765, -0.0089,  ..., -0.0986, -0.0151,  0.3643]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1426,  0.2943, -0.2977,  ..., -0.0059, -0.1510,  0.2142],
#          [ 0.1418, -0.0791, -0.1137,  ...,  0.2599, -0.0053, -0.1936],
#          [ 0.4859, -0.0917,  0.1386,  ..., -0.0019, -0.4429, -0.2793],
#          ...,
#          [ 0.3083, -0.3140,  0.1484,  ...,  0.1835, -0.9105,  0.1192],
#          [ 0.2134, -0.0352,  0.1111,  ..., -0.1908, -0.2832,  0.2886],
#          [ 0.4408, -0.2555, -0.1602,  ..., -0.3808,  0.2271,  0.4936]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0119,  0.3195, -0.4456,  ..., -0.1317,  0.0327, -0.1775],
#          [-0.0641,  0.0896, -0.3738,  ..., -0.5250,  0.2368,  0.0848],
#          [-0.3334, -0.8389,  0.1121,  ..., -0.2743,  0.7290, -0.4304],
#          ...,
#          [-0.1453,  0.1960, -0.4812,  ...,  0.1560, -0.0969, -0.0907],
#          [-0.2490, -0.3528, -0.1440,  ..., -0.3964, -0.4265, -0.0278],
#          [ 0.5205, -0.4674, -0.5675,  ..., -0.3998,  0.5997,  0.0822]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1243, -0.1492,  0.0763,  ..., -0.3899, -0.1230, -0.2863],
#          [-0.3438, -0.0646,  0.0673,  ...,  0.0715, -0.2095,  0.1872],
#          [-0.1614, -0.0079,  0.1361,  ...,  0.3874, -0.4111, -0.1361],
#          ...,
#          [ 0.1563, -0.1212,  0.0914,  ..., -0.5487, -0.7687, -0.0679],
#          [-0.1254, -0.6892,  0.1198,  ..., -0.0182, -0.4301, -0.2170],
#          [ 0.1536, -0.9765, -0.0089,  ..., -0.0986, -0.0151,  0.3643]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007877631112933159
# The value of j is: 3
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0175,  0.2057, -0.0782,  ..., -0.0279,  0.0352,  0.0082],
#          [ 0.1956, -0.2976,  0.2303,  ...,  0.4376,  0.0384, -0.1398],
#          [ 0.3205, -0.3689, -0.2152,  ..., -0.7155, -0.0725,  0.0410],
#          ...,
#          [ 0.2223, -0.0029,  0.0972,  ...,  0.3680,  0.2695, -0.1357],
#          [-0.0054, -0.3620,  0.1787,  ...,  0.4357, -0.2734,  0.0655],
#          [ 0.9236, -0.7818, -0.0607,  ..., -0.1908,  0.8062,  0.2503]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.0175,  0.2057, -0.0782,  ..., -0.0279,  0.0352,  0.0082],
#          [ 0.1956, -0.2976,  0.2303,  ...,  0.4376,  0.0384, -0.1398],
#          [ 0.3205, -0.3689, -0.2152,  ..., -0.7155, -0.0725,  0.0410],
#          ...,
#          [ 0.2223, -0.0029,  0.0972,  ...,  0.3680,  0.2695, -0.1357],
#          [-0.0054, -0.3620,  0.1787,  ...,  0.4357, -0.2734,  0.0655],
#          [ 0.9236, -0.7818, -0.0607,  ..., -0.1908,  0.8062,  0.2503]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007763928268104792
# The value of j is: 4
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 1.5362e-01,  1.1886e-01, -2.4250e-01,  ...,  3.5425e-03,
#            1.3682e-01, -2.6569e-01],
#          [-8.0485e-02, -1.1163e-01,  5.6861e-01,  ...,  8.4840e-04,
#           -2.2806e-01,  1.0890e-01],
#          [-1.3652e-01, -1.4831e-01,  4.2447e-01,  ...,  8.4605e-02,
#           -4.3976e-02, -1.5314e-01],
#          ...,
#          [ 6.4657e-02,  2.0793e-01, -3.7171e-01,  ...,  8.0846e-02,
#            2.0012e-01, -2.3846e-02],
#          [ 3.3139e-01, -6.8601e-01,  8.3459e-02,  ...,  1.7677e-01,
#           -1.8124e-01, -2.5392e-01],
#          [ 9.6665e-01, -6.8581e-01, -1.9695e-01,  ..., -2.2441e-01,
#            4.7043e-01, -2.3971e-02]]], grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 1.5362e-01,  1.1886e-01, -2.4250e-01,  ...,  3.5425e-03,
#            1.3682e-01, -2.6569e-01],
#          [-8.0485e-02, -1.1163e-01,  5.6861e-01,  ...,  8.4840e-04,
#           -2.2806e-01,  1.0890e-01],
#          [-1.3652e-01, -1.4831e-01,  4.2447e-01,  ...,  8.4605e-02,
#           -4.3976e-02, -1.5314e-01],
#          ...,
#          [ 6.4657e-02,  2.0793e-01, -3.7171e-01,  ...,  8.0846e-02,
#            2.0012e-01, -2.3846e-02],
#          [ 3.3139e-01, -6.8601e-01,  8.3459e-02,  ...,  1.7677e-01,
#           -1.8124e-01, -2.5392e-01],
#          [ 9.6665e-01, -6.8581e-01, -1.9695e-01,  ..., -2.2441e-01,
#            4.7043e-01, -2.3971e-02]]], grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.3427,  0.4371, -0.3057,  ..., -0.3938,  0.0910, -0.1090],
#          [ 0.2019,  0.0041,  0.1309,  ..., -0.2490, -0.3408,  0.1541],
#          [ 0.2102,  0.3938,  0.0798,  ..., -0.3599, -0.4844, -0.1019],
#          ...,
#          [ 0.7145, -0.6292,  0.0459,  ...,  0.0543, -0.7132, -0.8087],
#          [-0.1856, -0.4829, -0.1041,  ..., -0.1662, -0.4629,  0.0397],
#          [ 0.4178, -0.0799, -0.2289,  ..., -0.9114,  0.4823,  0.1216]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 1.5362e-01,  1.1886e-01, -2.4250e-01,  ...,  3.5425e-03,
#            1.3682e-01, -2.6569e-01],
#          [-8.0485e-02, -1.1163e-01,  5.6861e-01,  ...,  8.4840e-04,
#           -2.2806e-01,  1.0890e-01],
#          [-1.3652e-01, -1.4831e-01,  4.2447e-01,  ...,  8.4605e-02,
#           -4.3976e-02, -1.5314e-01],
#          ...,
#          [ 6.4657e-02,  2.0793e-01, -3.7171e-01,  ...,  8.0846e-02,
#            2.0012e-01, -2.3846e-02],
#          [ 3.3139e-01, -6.8601e-01,  8.3459e-02,  ...,  1.7677e-01,
#           -1.8124e-01, -2.5392e-01],
#          [ 9.6665e-01, -6.8581e-01, -1.9695e-01,  ..., -2.2441e-01,
#            4.7043e-01, -2.3971e-02]]], grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.3427,  0.4371, -0.3057,  ..., -0.3938,  0.0910, -0.1090],
#          [ 0.2019,  0.0041,  0.1309,  ..., -0.2490, -0.3408,  0.1541],
#          [ 0.2102,  0.3938,  0.0798,  ..., -0.3599, -0.4844, -0.1019],
#          ...,
#          [ 0.7145, -0.6292,  0.0459,  ...,  0.0543, -0.7132, -0.8087],
#          [-0.1856, -0.4829, -0.1041,  ..., -0.1662, -0.4629,  0.0397],
#          [ 0.4178, -0.0799, -0.2289,  ..., -0.9114,  0.4823,  0.1216]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007870787754654884
# The value of j is: 5
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.0700,  0.3497, -0.4913,  ...,  0.1138,  0.0656,  0.0022],
#          [ 0.2549, -0.6590,  0.1569,  ...,  0.3745, -0.0023, -0.2892],
#          [ 0.1072, -0.5213, -0.2161,  ..., -0.7187, -0.2699, -0.0048],
#          ...,
#          [-0.2556,  0.1394,  0.1836,  ...,  0.1458, -0.1466,  0.0690],
#          [ 0.1870, -0.2089, -0.2609,  ...,  0.3017,  0.2708,  0.4841],
#          [ 0.3683, -0.3734, -0.8897,  ...,  0.4351,  0.4683,  0.1444]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[-0.0700,  0.3497, -0.4913,  ...,  0.1138,  0.0656,  0.0022],
#          [ 0.2549, -0.6590,  0.1569,  ...,  0.3745, -0.0023, -0.2892],
#          [ 0.1072, -0.5213, -0.2161,  ..., -0.7187, -0.2699, -0.0048],
#          ...,
#          [-0.2556,  0.1394,  0.1836,  ...,  0.1458, -0.1466,  0.0690],
#          [ 0.1870, -0.2089, -0.2609,  ...,  0.3017,  0.2708,  0.4841],
#          [ 0.3683, -0.3734, -0.8897,  ...,  0.4351,  0.4683,  0.1444]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-6.5004e-02,  2.8102e-01, -4.5292e-01,  ...,  3.2639e-02,
#            2.0919e-01, -1.1744e-01],
#          [-1.3121e-01, -4.6697e-01, -1.4993e-01,  ...,  5.2579e-01,
#            3.7546e-01,  2.5684e-01],
#          [-1.7421e-01,  3.9196e-01, -6.1204e-01,  ..., -2.9210e-01,
#           -1.5744e-01, -2.8419e-01],
#          ...,
#          [-8.4671e-04, -2.1452e-01, -1.8779e-01,  ...,  5.8811e-02,
#           -6.4577e-01,  5.7820e-01],
#          [-1.2477e-01, -3.4415e-01, -2.6840e-01,  ...,  4.2131e-01,
#           -4.0665e-01, -9.8790e-02],
#          [ 3.5879e-01, -1.7996e-01, -8.9388e-01,  ..., -6.4211e-01,
#            1.1452e+00,  1.8892e-01]]], grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[-0.0700,  0.3497, -0.4913,  ...,  0.1138,  0.0656,  0.0022],
#          [ 0.2549, -0.6590,  0.1569,  ...,  0.3745, -0.0023, -0.2892],
#          [ 0.1072, -0.5213, -0.2161,  ..., -0.7187, -0.2699, -0.0048],
#          ...,
#          [-0.2556,  0.1394,  0.1836,  ...,  0.1458, -0.1466,  0.0690],
#          [ 0.1870, -0.2089, -0.2609,  ...,  0.3017,  0.2708,  0.4841],
#          [ 0.3683, -0.3734, -0.8897,  ...,  0.4351,  0.4683,  0.1444]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-6.5004e-02,  2.8102e-01, -4.5292e-01,  ...,  3.2639e-02,
#            2.0919e-01, -1.1744e-01],
#          [-1.3121e-01, -4.6697e-01, -1.4993e-01,  ...,  5.2579e-01,
#            3.7546e-01,  2.5684e-01],
#          [-1.7421e-01,  3.9196e-01, -6.1204e-01,  ..., -2.9210e-01,
#           -1.5744e-01, -2.8419e-01],
#          ...,
#          [-8.4671e-04, -2.1452e-01, -1.8779e-01,  ...,  5.8811e-02,
#           -6.4577e-01,  5.7820e-01],
#          [-1.2477e-01, -3.4415e-01, -2.6840e-01,  ...,  4.2131e-01,
#           -4.0665e-01, -9.8790e-02],
#          [ 3.5879e-01, -1.7996e-01, -8.9388e-01,  ..., -6.4211e-01,
#            1.1452e+00,  1.8892e-01]]], grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007805286440998316
# The value of j is: 6
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1709, -0.1579, -0.0324,  ..., -0.0471,  0.1381, -0.1484],
#          [-0.1650,  0.0662,  0.0643,  ...,  0.0322, -0.5163,  0.4303],
#          [ 0.5637, -0.2179,  0.0326,  ..., -0.2276,  0.0145, -0.2777],
#          ...,
#          [-0.1727, -0.1431, -0.1052,  ...,  0.4072,  0.4314,  0.6695],
#          [-0.1800, -0.3819, -0.1000,  ...,  0.1114, -0.0380, -0.1497],
#          [ 0.8596, -1.0738, -0.2572,  ..., -0.1079,  0.9451,  0.0743]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1709, -0.1579, -0.0324,  ..., -0.0471,  0.1381, -0.1484],
#          [-0.1650,  0.0662,  0.0643,  ...,  0.0322, -0.5163,  0.4303],
#          [ 0.5637, -0.2179,  0.0326,  ..., -0.2276,  0.0145, -0.2777],
#          ...,
#          [-0.1727, -0.1431, -0.1052,  ...,  0.4072,  0.4314,  0.6695],
#          [-0.1800, -0.3819, -0.1000,  ...,  0.1114, -0.0380, -0.1497],
#          [ 0.8596, -1.0738, -0.2572,  ..., -0.1079,  0.9451,  0.0743]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007326402701437473
# The value of j is: 7
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0973, -0.3859, -0.3158,  ..., -0.0748, -0.0066, -0.3870],
#          [-0.6493, -0.8502,  0.0844,  ...,  0.6566,  0.0595,  0.8830],
#          [ 0.2218, -0.6500, -0.4012,  ..., -0.4718,  0.2516,  0.1116],
#          ...,
#          [ 0.5835, -0.4278, -0.5139,  ...,  0.9208, -0.1659, -0.1020],
#          [-0.0179, -0.3237, -0.1374,  ..., -0.0455, -0.1197, -0.7807],
#          [ 0.7358, -1.1508, -0.4972,  ...,  0.5456, -0.5152,  0.3118]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0973, -0.3859, -0.3158,  ..., -0.0748, -0.0066, -0.3870],
#          [-0.6493, -0.8502,  0.0844,  ...,  0.6566,  0.0595,  0.8830],
#          [ 0.2218, -0.6500, -0.4012,  ..., -0.4718,  0.2516,  0.1116],
#          ...,
#          [ 0.5835, -0.4278, -0.5139,  ...,  0.9208, -0.1659, -0.1020],
#          [-0.0179, -0.3237, -0.1374,  ..., -0.0455, -0.1197, -0.7807],
#          [ 0.7358, -1.1508, -0.4972,  ...,  0.5456, -0.5152,  0.3118]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.0224,  0.6415,  0.1619,  ...,  0.3266, -0.0333, -0.0172],
#          [-0.6871,  0.4991,  0.1909,  ...,  0.0914, -0.1656, -0.1029],
#          [-0.1545, -0.1220,  0.1153,  ..., -0.0211,  0.4784, -0.0919],
#          ...,
#          [ 0.5383,  0.2382, -0.9833,  ...,  0.7174, -0.1145,  0.6282],
#          [-0.0017,  0.1184, -0.3421,  ...,  0.3252,  0.3822,  0.9030],
#          [ 0.7224, -0.1127,  0.0877,  ...,  0.7674, -0.3247,  0.4045]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0973, -0.3859, -0.3158,  ..., -0.0748, -0.0066, -0.3870],
#          [-0.6493, -0.8502,  0.0844,  ...,  0.6566,  0.0595,  0.8830],
#          [ 0.2218, -0.6500, -0.4012,  ..., -0.4718,  0.2516,  0.1116],
#          ...,
#          [ 0.5835, -0.4278, -0.5139,  ...,  0.9208, -0.1659, -0.1020],
#          [-0.0179, -0.3237, -0.1374,  ..., -0.0455, -0.1197, -0.7807],
#          [ 0.7358, -1.1508, -0.4972,  ...,  0.5456, -0.5152,  0.3118]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-0.0224,  0.6415,  0.1619,  ...,  0.3266, -0.0333, -0.0172],
#          [-0.6871,  0.4991,  0.1909,  ...,  0.0914, -0.1656, -0.1029],
#          [-0.1545, -0.1220,  0.1153,  ..., -0.0211,  0.4784, -0.0919],
#          ...,
#          [ 0.5383,  0.2382, -0.9833,  ...,  0.7174, -0.1145,  0.6282],
#          [-0.0017,  0.1184, -0.3421,  ...,  0.3252,  0.3822,  0.9030],
#          [ 0.7224, -0.1127,  0.0877,  ...,  0.7674, -0.3247,  0.4045]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.2665,  0.2283,  0.0013,  ...,  0.2498, -0.3011, -0.1195],
#          [ 0.0893,  0.3067,  0.4214,  ..., -0.0038,  0.0805, -0.1780],
#          [-0.0350,  0.1260,  0.1763,  ...,  0.2719,  0.3106, -0.2935],
#          ...,
#          [ 0.1004,  0.0280, -0.6499,  ...,  0.9682, -0.1237, -0.2862],
#          [ 0.0555,  0.4011, -0.9526,  ...,  1.0586,  0.0618, -0.1651],
#          [ 0.9574, -0.1663, -0.4125,  ...,  0.5252, -0.1329,  0.3157]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0973, -0.3859, -0.3158,  ..., -0.0748, -0.0066, -0.3870],
#          [-0.6493, -0.8502,  0.0844,  ...,  0.6566,  0.0595,  0.8830],
#          [ 0.2218, -0.6500, -0.4012,  ..., -0.4718,  0.2516,  0.1116],
#          ...,
#          [ 0.5835, -0.4278, -0.5139,  ...,  0.9208, -0.1659, -0.1020],
#          [-0.0179, -0.3237, -0.1374,  ..., -0.0455, -0.1197, -0.7807],
#          [ 0.7358, -1.1508, -0.4972,  ...,  0.5456, -0.5152,  0.3118]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-0.0224,  0.6415,  0.1619,  ...,  0.3266, -0.0333, -0.0172],
#          [-0.6871,  0.4991,  0.1909,  ...,  0.0914, -0.1656, -0.1029],
#          [-0.1545, -0.1220,  0.1153,  ..., -0.0211,  0.4784, -0.0919],
#          ...,
#          [ 0.5383,  0.2382, -0.9833,  ...,  0.7174, -0.1145,  0.6282],
#          [-0.0017,  0.1184, -0.3421,  ...,  0.3252,  0.3822,  0.9030],
#          [ 0.7224, -0.1127,  0.0877,  ...,  0.7674, -0.3247,  0.4045]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.2665,  0.2283,  0.0013,  ...,  0.2498, -0.3011, -0.1195],
#          [ 0.0893,  0.3067,  0.4214,  ..., -0.0038,  0.0805, -0.1780],
#          [-0.0350,  0.1260,  0.1763,  ...,  0.2719,  0.3106, -0.2935],
#          ...,
#          [ 0.1004,  0.0280, -0.6499,  ...,  0.9682, -0.1237, -0.2862],
#          [ 0.0555,  0.4011, -0.9526,  ...,  1.0586,  0.0618, -0.1651],
#          [ 0.9574, -0.1663, -0.4125,  ...,  0.5252, -0.1329,  0.3157]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0315, -0.5806, -0.4397,  ..., -0.2126, -0.2046,  0.0720],
#          [ 0.1944,  0.0799, -0.2189,  ...,  0.1690,  0.6094,  0.1172],
#          [ 0.1524, -0.3070,  0.0569,  ...,  0.0734, -0.4083, -0.1544],
#          ...,
#          [ 0.2129, -1.4411, -0.0881,  ...,  0.1408, -0.1155, -0.5122],
#          [ 0.4385, -1.2769, -0.9083,  ...,  0.1037, -0.4328, -0.0583],
#          [ 1.0517, -0.7861, -0.3665,  ..., -0.0857,  0.0312,  0.8167]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1100,  0.2648, -0.3034,  ...,  0.0513,  0.0275,  0.2874],
#          [-0.0188,  0.1576,  0.2907,  ..., -0.0575, -0.1265, -0.0547],
#          [ 0.0749,  0.1513,  0.3421,  ...,  0.1314, -0.3550, -0.1036],
#          ...,
#          [ 0.1530, -0.0045,  0.4005,  ...,  1.0973, -0.7373,  0.1130],
#          [-0.8999, -0.2771,  0.0181,  ...,  0.7297,  0.0684,  0.2457],
#          [ 0.9553, -0.2405, -0.1286,  ...,  0.1574, -0.3802,  0.6576]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0651,  0.2304, -0.2434,  ...,  0.3946, -0.7185,  0.0806],
#          [-0.3679, -0.3212,  0.0445,  ...,  0.0837, -0.2948,  0.6086],
#          [ 0.2569, -0.7358,  0.0356,  ...,  0.9516,  0.1669, -0.0995],
#          ...,
#          [ 0.2385,  0.7676, -0.3845,  ...,  1.6708, -1.0266, -0.3287],
#          [ 0.1745, -0.1074,  0.1116,  ...,  0.9892, -0.6044, -0.2731],
#          [ 0.6265, -0.2461, -0.2894,  ...,  1.8949, -0.7844,  0.4381]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1618, -0.3332,  0.1049,  ...,  0.1003, -0.3262, -0.0801],
#          [ 0.1070, -0.6509, -0.3398,  ...,  0.6792, -0.2191, -0.4042],
#          [-0.0765, -0.5702,  0.1594,  ...,  0.1094,  0.0224, -0.6368],
#          ...,
#          [ 0.0859, -0.2407,  0.0454,  ...,  0.7201, -0.1443, -0.6257],
#          [ 0.2511, -0.4848, -0.1296,  ...,  0.4073,  0.0828, -0.5378],
#          [ 1.1478, -1.1798, -0.2136,  ...,  1.1846, -0.0433,  0.3635]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0973, -0.3859, -0.3158,  ..., -0.0748, -0.0066, -0.3870],
#          [-0.6493, -0.8502,  0.0844,  ...,  0.6566,  0.0595,  0.8830],
#          [ 0.2218, -0.6500, -0.4012,  ..., -0.4718,  0.2516,  0.1116],
#          ...,
#          [ 0.5835, -0.4278, -0.5139,  ...,  0.9208, -0.1659, -0.1020],
#          [-0.0179, -0.3237, -0.1374,  ..., -0.0455, -0.1197, -0.7807],
#          [ 0.7358, -1.1508, -0.4972,  ...,  0.5456, -0.5152,  0.3118]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-0.0224,  0.6415,  0.1619,  ...,  0.3266, -0.0333, -0.0172],
#          [-0.6871,  0.4991,  0.1909,  ...,  0.0914, -0.1656, -0.1029],
#          [-0.1545, -0.1220,  0.1153,  ..., -0.0211,  0.4784, -0.0919],
#          ...,
#          [ 0.5383,  0.2382, -0.9833,  ...,  0.7174, -0.1145,  0.6282],
#          [-0.0017,  0.1184, -0.3421,  ...,  0.3252,  0.3822,  0.9030],
#          [ 0.7224, -0.1127,  0.0877,  ...,  0.7674, -0.3247,  0.4045]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.2665,  0.2283,  0.0013,  ...,  0.2498, -0.3011, -0.1195],
#          [ 0.0893,  0.3067,  0.4214,  ..., -0.0038,  0.0805, -0.1780],
#          [-0.0350,  0.1260,  0.1763,  ...,  0.2719,  0.3106, -0.2935],
#          ...,
#          [ 0.1004,  0.0280, -0.6499,  ...,  0.9682, -0.1237, -0.2862],
#          [ 0.0555,  0.4011, -0.9526,  ...,  1.0586,  0.0618, -0.1651],
#          [ 0.9574, -0.1663, -0.4125,  ...,  0.5252, -0.1329,  0.3157]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.0315, -0.5806, -0.4397,  ..., -0.2126, -0.2046,  0.0720],
#          [ 0.1944,  0.0799, -0.2189,  ...,  0.1690,  0.6094,  0.1172],
#          [ 0.1524, -0.3070,  0.0569,  ...,  0.0734, -0.4083, -0.1544],
#          ...,
#          [ 0.2129, -1.4411, -0.0881,  ...,  0.1408, -0.1155, -0.5122],
#          [ 0.4385, -1.2769, -0.9083,  ...,  0.1037, -0.4328, -0.0583],
#          [ 1.0517, -0.7861, -0.3665,  ..., -0.0857,  0.0312,  0.8167]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.00833608116954565
# The value of j is: 8
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 6.0630e-03,  1.1266e-01, -1.4931e-01,  ...,  9.0778e-02,
#            2.0365e-01,  1.5837e-01],
#          [ 1.2098e-01, -1.0537e+00,  1.8463e-01,  ...,  2.6104e-01,
#            8.9577e-01, -5.9845e-01],
#          [ 7.0614e-01, -1.3442e+00, -3.6737e-01,  ..., -1.8792e-01,
#            9.0476e-02, -7.6548e-01],
#          ...,
#          [ 4.0893e-01, -4.4749e-01, -1.2734e-03,  ...,  1.6667e-01,
#           -9.9540e-02, -3.4663e-01],
#          [-2.4233e-01, -7.5884e-01, -5.9592e-03,  ..., -5.9246e-01,
#           -2.7688e-01, -4.1205e-02],
#          [ 8.7961e-01, -7.5033e-01, -2.2556e-01,  ...,  6.8543e-02,
#            3.0878e-01,  4.1120e-01]]], grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 6.0630e-03,  1.1266e-01, -1.4931e-01,  ...,  9.0778e-02,
#            2.0365e-01,  1.5837e-01],
#          [ 1.2098e-01, -1.0537e+00,  1.8463e-01,  ...,  2.6104e-01,
#            8.9577e-01, -5.9845e-01],
#          [ 7.0614e-01, -1.3442e+00, -3.6737e-01,  ..., -1.8792e-01,
#            9.0476e-02, -7.6548e-01],
#          ...,
#          [ 4.0893e-01, -4.4749e-01, -1.2734e-03,  ...,  1.6667e-01,
#           -9.9540e-02, -3.4663e-01],
#          [-2.4233e-01, -7.5884e-01, -5.9592e-03,  ..., -5.9246e-01,
#           -2.7688e-01, -4.1205e-02],
#          [ 8.7961e-01, -7.5033e-01, -2.2556e-01,  ...,  6.8543e-02,
#            3.0878e-01,  4.1120e-01]]], grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007914979010820389
# The value of j is: 9
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.2546, -0.1364, -0.2521,  ..., -0.0474,  0.1166, -0.0163],
#          [ 0.3705,  0.2150, -0.1260,  ...,  0.2196,  1.1675,  0.1181],
#          [ 0.5894, -0.7484, -0.3446,  ..., -0.1000, -0.1086, -0.6803],
#          ...,
#          [ 0.2957, -0.2850, -0.0423,  ..., -0.0344,  0.1402,  0.2022],
#          [ 0.0196, -0.4586,  0.0226,  ...,  0.1865, -0.0652, -0.1971],
#          [ 1.6117, -1.1162, -0.1477,  ..., -0.4844,  0.3364,  0.4746]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.2546, -0.1364, -0.2521,  ..., -0.0474,  0.1166, -0.0163],
#          [ 0.3705,  0.2150, -0.1260,  ...,  0.2196,  1.1675,  0.1181],
#          [ 0.5894, -0.7484, -0.3446,  ..., -0.1000, -0.1086, -0.6803],
#          ...,
#          [ 0.2957, -0.2850, -0.0423,  ..., -0.0344,  0.1402,  0.2022],
#          [ 0.0196, -0.4586,  0.0226,  ...,  0.1865, -0.0652, -0.1971],
#          [ 1.6117, -1.1162, -0.1477,  ..., -0.4844,  0.3364,  0.4746]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007694373372942209
# The value of j is: 10
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.0831,  0.1737, -0.3172,  ..., -0.1601,  0.0893, -0.1561],
#          [-0.3385, -0.4654, -0.5181,  ...,  0.6856,  0.3271,  0.2265],
#          [-0.4021, -0.6858,  0.2329,  ...,  0.4273,  0.4693,  0.2268],
#          ...,
#          [ 0.2132, -0.1137, -0.2216,  ...,  0.4546, -0.3339,  0.1355],
#          [ 0.1029, -0.2533, -0.1757,  ...,  0.1329, -0.1716, -0.1685],
#          [ 0.5216, -0.2664, -0.3654,  ..., -0.1835,  0.6502, -0.0539]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[-0.0831,  0.1737, -0.3172,  ..., -0.1601,  0.0893, -0.1561],
#          [-0.3385, -0.4654, -0.5181,  ...,  0.6856,  0.3271,  0.2265],
#          [-0.4021, -0.6858,  0.2329,  ...,  0.4273,  0.4693,  0.2268],
#          ...,
#          [ 0.2132, -0.1137, -0.2216,  ...,  0.4546, -0.3339,  0.1355],
#          [ 0.1029, -0.2533, -0.1757,  ...,  0.1329, -0.1716, -0.1685],
#          [ 0.5216, -0.2664, -0.3654,  ..., -0.1835,  0.6502, -0.0539]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1840,  0.3652, -0.1438,  ..., -0.1114,  0.1412, -0.1559],
#          [-0.0571, -0.1427, -0.9063,  ...,  0.2414,  0.1959, -0.2961],
#          [ 0.1071, -0.7254, -0.6118,  ..., -0.0504, -0.0110, -0.5284],
#          ...,
#          [ 0.0868,  0.0448,  0.0501,  ...,  0.4347, -0.2518,  0.3208],
#          [ 0.0486, -0.2901,  0.0470,  ...,  0.3726, -0.1586,  0.1573],
#          [ 0.8936, -0.4390, -1.0516,  ...,  0.0100,  0.7956,  0.4870]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[-0.0831,  0.1737, -0.3172,  ..., -0.1601,  0.0893, -0.1561],
#          [-0.3385, -0.4654, -0.5181,  ...,  0.6856,  0.3271,  0.2265],
#          [-0.4021, -0.6858,  0.2329,  ...,  0.4273,  0.4693,  0.2268],
#          ...,
#          [ 0.2132, -0.1137, -0.2216,  ...,  0.4546, -0.3339,  0.1355],
#          [ 0.1029, -0.2533, -0.1757,  ...,  0.1329, -0.1716, -0.1685],
#          [ 0.5216, -0.2664, -0.3654,  ..., -0.1835,  0.6502, -0.0539]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1840,  0.3652, -0.1438,  ..., -0.1114,  0.1412, -0.1559],
#          [-0.0571, -0.1427, -0.9063,  ...,  0.2414,  0.1959, -0.2961],
#          [ 0.1071, -0.7254, -0.6118,  ..., -0.0504, -0.0110, -0.5284],
#          ...,
#          [ 0.0868,  0.0448,  0.0501,  ...,  0.4347, -0.2518,  0.3208],
#          [ 0.0486, -0.2901,  0.0470,  ...,  0.3726, -0.1586,  0.1573],
#          [ 0.8936, -0.4390, -1.0516,  ...,  0.0100,  0.7956,  0.4870]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007701744791120291
# The value of j is: 11
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1562,  0.0999, -0.3452,  ..., -0.0957,  0.1325,  0.0400],
#          [-0.0348,  0.5540,  0.3532,  ...,  0.2556,  0.2115, -0.3457],
#          [ 0.0496, -0.8111, -0.0560,  ...,  0.2278, -0.8156, -0.5207],
#          ...,
#          [ 0.1901,  0.2953, -0.4622,  ...,  0.3871, -0.5102,  0.6314],
#          [ 0.1051, -0.0180, -0.1467,  ..., -0.4985, -0.0701, -0.1485],
#          [ 0.9781, -0.5388, -0.4691,  ...,  0.0726,  0.0290,  0.4246]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1562,  0.0999, -0.3452,  ..., -0.0957,  0.1325,  0.0400],
#          [-0.0348,  0.5540,  0.3532,  ...,  0.2556,  0.2115, -0.3457],
#          [ 0.0496, -0.8111, -0.0560,  ...,  0.2278, -0.8156, -0.5207],
#          ...,
#          [ 0.1901,  0.2953, -0.4622,  ...,  0.3871, -0.5102,  0.6314],
#          [ 0.1051, -0.0180, -0.1467,  ..., -0.4985, -0.0701, -0.1485],
#          [ 0.9781, -0.5388, -0.4691,  ...,  0.0726,  0.0290,  0.4246]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.1255,  0.3194, -0.1598,  ..., -0.0101,  0.3745, -0.1367],
#          [-0.1885, -0.5975,  0.3638,  ...,  0.9649,  0.0608,  0.1123],
#          [ 0.2332, -0.1123, -0.1733,  ...,  0.1358, -0.5367,  0.2409],
#          ...,
#          [-0.1630,  0.1214,  0.3149,  ...,  0.6047,  0.2954,  0.1223],
#          [-0.2942, -0.2985,  0.1221,  ...,  0.2365, -0.1933, -0.1952],
#          [ 1.2632, -0.6671,  0.1968,  ...,  0.5651,  0.6516, -0.1728]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.1562,  0.0999, -0.3452,  ..., -0.0957,  0.1325,  0.0400],
#          [-0.0348,  0.5540,  0.3532,  ...,  0.2556,  0.2115, -0.3457],
#          [ 0.0496, -0.8111, -0.0560,  ...,  0.2278, -0.8156, -0.5207],
#          ...,
#          [ 0.1901,  0.2953, -0.4622,  ...,  0.3871, -0.5102,  0.6314],
#          [ 0.1051, -0.0180, -0.1467,  ..., -0.4985, -0.0701, -0.1485],
#          [ 0.9781, -0.5388, -0.4691,  ...,  0.0726,  0.0290,  0.4246]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-0.1255,  0.3194, -0.1598,  ..., -0.0101,  0.3745, -0.1367],
#          [-0.1885, -0.5975,  0.3638,  ...,  0.9649,  0.0608,  0.1123],
#          [ 0.2332, -0.1123, -0.1733,  ...,  0.1358, -0.5367,  0.2409],
#          ...,
#          [-0.1630,  0.1214,  0.3149,  ...,  0.6047,  0.2954,  0.1223],
#          [-0.2942, -0.2985,  0.1221,  ...,  0.2365, -0.1933, -0.1952],
#          [ 1.2632, -0.6671,  0.1968,  ...,  0.5651,  0.6516, -0.1728]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.008101506158709526
# The value of j is: 12
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 1.1930e-01,  3.3479e-01, -1.0520e-01,  ..., -9.5488e-02,
#            3.2088e-01,  1.5026e-02],
#          [ 8.6467e-02, -4.5517e-01,  1.9135e-01,  ...,  3.0991e-01,
#            5.0079e-01,  3.4684e-01],
#          [ 4.7497e-01, -7.7151e-01, -1.3034e-03,  ...,  8.3753e-01,
#            3.9320e-05,  6.9354e-01],
#          ...,
#          [-3.8065e-01, -3.9012e-01, -2.3032e-01,  ...,  1.6536e-01,
#           -2.1176e-01,  6.0850e-02],
#          [-1.4503e-01, -3.9579e-01, -3.9590e-03,  ...,  9.4901e-02,
#           -3.8550e-01, -8.1790e-02],
#          [ 6.9199e-01, -1.3424e-01, -3.7116e-01,  ..., -1.7311e-01,
#            8.7773e-01, -8.4905e-02]]], grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 1.1930e-01,  3.3479e-01, -1.0520e-01,  ..., -9.5488e-02,
#            3.2088e-01,  1.5026e-02],
#          [ 8.6467e-02, -4.5517e-01,  1.9135e-01,  ...,  3.0991e-01,
#            5.0079e-01,  3.4684e-01],
#          [ 4.7497e-01, -7.7151e-01, -1.3034e-03,  ...,  8.3753e-01,
#            3.9320e-05,  6.9354e-01],
#          ...,
#          [-3.8065e-01, -3.9012e-01, -2.3032e-01,  ...,  1.6536e-01,
#           -2.1176e-01,  6.0850e-02],
#          [-1.4503e-01, -3.9579e-01, -3.9590e-03,  ...,  9.4901e-02,
#           -3.8550e-01, -8.1790e-02],
#          [ 6.9199e-01, -1.3424e-01, -3.7116e-01,  ..., -1.7311e-01,
#            8.7773e-01, -8.4905e-02]]], grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007665394805371761
# The value of j is: 13
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.1283,  0.0319, -0.2260,  ...,  0.0290,  0.0222, -0.0555],
#          [-0.3275, -0.7913, -0.0555,  ...,  0.5811,  0.4896,  0.3757],
#          [-0.0634, -0.8223, -0.2819,  ...,  0.5827, -0.3132,  0.1498],
#          ...,
#          [-0.1228,  0.0291, -0.1534,  ...,  0.6816, -0.1021, -0.1733],
#          [-0.0944, -0.4412,  0.0537,  ...,  0.1959, -0.1783,  0.1726],
#          [ 0.5139, -0.8669, -0.6437,  ...,  0.1915,  0.7537,  0.2717]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[-0.1283,  0.0319, -0.2260,  ...,  0.0290,  0.0222, -0.0555],
# ...
#          [ 0.2713, -0.6001, -0.5756,  ..., -0.2915, -0.3559, -0.5089],
#          [ 0.4222, -0.9761, -0.9425,  ...,  0.3852, -0.3556, -0.4322],
#          [ 0.7551, -0.6424, -0.9205,  ...,  0.2313, -0.5761,  0.4775]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1156,  0.1565, -0.3174,  ...,  0.2750, -0.3842,  0.1569],
#          [-0.2807,  0.0475, -0.0116,  ..., -0.4800, -0.3432, -0.1715],
#          [ 0.3539,  0.0681, -0.0877,  ..., -0.1301,  0.4568, -0.2381],
#          ...,
#          [-0.2787,  0.0856, -0.1611,  ...,  0.8019, -0.7588, -0.5579],
#          [-0.1479, -0.0292,  0.0175,  ...,  0.9023, -0.5501, -0.1577],
#          [ 0.7881, -0.5376, -0.0121,  ...,  1.2485, -0.6135,  0.3354]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.3496, -0.4191,  0.1702,  ...,  0.0831, -0.1034, -0.0020],
#          [-0.7998, -0.5504, -0.1231,  ..., -0.2085,  0.2780, -0.0683],
#          [-0.8269, -0.7252, -0.1034,  ..., -0.1517,  0.5639,  0.1000],
#          ...,
#          [ 0.2486, -0.1840,  0.0235,  ..., -0.1645,  0.2530, -0.1258],
#          [ 0.0523, -0.6069, -0.0336,  ...,  0.0941,  0.3626,  0.1455],
#          [ 1.2233, -1.2535, -0.0156,  ...,  0.9387,  0.3385,  0.2328]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.2188,  0.1704, -0.3597,  ..., -0.0066,  0.0817,  0.2762],
#          [-0.0931, -0.3944, -0.3717,  ...,  0.9438, -0.1165, -0.6112],
#          [ 0.4775, -0.3140, -0.0541,  ...,  0.7510, -0.0326,  0.2622],
#          ...,
#          [ 0.2713, -0.6001, -0.5756,  ..., -0.2915, -0.3559, -0.5089],
#          [ 0.4222, -0.9761, -0.9425,  ...,  0.3852, -0.3556, -0.4322],
#          [ 0.7551, -0.6424, -0.9205,  ...,  0.2313, -0.5761,  0.4775]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1156,  0.1565, -0.3174,  ...,  0.2750, -0.3842,  0.1569],
#          [-0.2807,  0.0475, -0.0116,  ..., -0.4800, -0.3432, -0.1715],
#          [ 0.3539,  0.0681, -0.0877,  ..., -0.1301,  0.4568, -0.2381],
#          ...,
#          [-0.2787,  0.0856, -0.1611,  ...,  0.8019, -0.7588, -0.5579],
#          [-0.1479, -0.0292,  0.0175,  ...,  0.9023, -0.5501, -0.1577],
#          [ 0.7881, -0.5376, -0.0121,  ...,  1.2485, -0.6135,  0.3354]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.3496, -0.4191,  0.1702,  ...,  0.0831, -0.1034, -0.0020],
#          [-0.7998, -0.5504, -0.1231,  ..., -0.2085,  0.2780, -0.0683],
#          [-0.8269, -0.7252, -0.1034,  ..., -0.1517,  0.5639,  0.1000],
#          ...,
#          [ 0.2486, -0.1840,  0.0235,  ..., -0.1645,  0.2530, -0.1258],
#          [ 0.0523, -0.6069, -0.0336,  ...,  0.0941,  0.3626,  0.1455],
#          [ 1.2233, -1.2535, -0.0156,  ...,  0.9387,  0.3385,  0.2328]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.2349,  0.4681, -0.0989,  ...,  0.1108, -0.2418,  0.0014],
#          [ 0.4919, -0.2225,  0.1894,  ..., -0.2463,  0.5698,  0.3943],
#          [ 0.0604, -1.0796, -0.2112,  ..., -0.1562, -0.0254, -0.2654],
#          ...,
#          [ 0.0600,  0.2002,  0.2408,  ...,  0.2803, -0.8209, -0.0972],
#          [-0.2994, -0.1020, -0.1225,  ...,  0.3097, -0.7325,  0.3468],
#          [ 0.6926, -0.4992, -0.0161,  ...,  0.1480, -0.2440,  0.5284]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.2188,  0.1704, -0.3597,  ..., -0.0066,  0.0817,  0.2762],
#          [-0.0931, -0.3944, -0.3717,  ...,  0.9438, -0.1165, -0.6112],
#          [ 0.4775, -0.3140, -0.0541,  ...,  0.7510, -0.0326,  0.2622],
#          ...,
#          [ 0.2713, -0.6001, -0.5756,  ..., -0.2915, -0.3559, -0.5089],
#          [ 0.4222, -0.9761, -0.9425,  ...,  0.3852, -0.3556, -0.4322],
#          [ 0.7551, -0.6424, -0.9205,  ...,  0.2313, -0.5761,  0.4775]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1156,  0.1565, -0.3174,  ...,  0.2750, -0.3842,  0.1569],
#          [-0.2807,  0.0475, -0.0116,  ..., -0.4800, -0.3432, -0.1715],
#          [ 0.3539,  0.0681, -0.0877,  ..., -0.1301,  0.4568, -0.2381],
#          ...,
#          [-0.2787,  0.0856, -0.1611,  ...,  0.8019, -0.7588, -0.5579],
#          [-0.1479, -0.0292,  0.0175,  ...,  0.9023, -0.5501, -0.1577],
#          [ 0.7881, -0.5376, -0.0121,  ...,  1.2485, -0.6135,  0.3354]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.3496, -0.4191,  0.1702,  ...,  0.0831, -0.1034, -0.0020],
#          [-0.7998, -0.5504, -0.1231,  ..., -0.2085,  0.2780, -0.0683],
#          [-0.8269, -0.7252, -0.1034,  ..., -0.1517,  0.5639,  0.1000],
#          ...,
#          [ 0.2486, -0.1840,  0.0235,  ..., -0.1645,  0.2530, -0.1258],
#          [ 0.0523, -0.6069, -0.0336,  ...,  0.0941,  0.3626,  0.1455],
#          [ 1.2233, -1.2535, -0.0156,  ...,  0.9387,  0.3385,  0.2328]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.2349,  0.4681, -0.0989,  ...,  0.1108, -0.2418,  0.0014],
#          [ 0.4919, -0.2225,  0.1894,  ..., -0.2463,  0.5698,  0.3943],
#          [ 0.0604, -1.0796, -0.2112,  ..., -0.1562, -0.0254, -0.2654],
#          ...,
#          [ 0.0600,  0.2002,  0.2408,  ...,  0.2803, -0.8209, -0.0972],
#          [-0.2994, -0.1020, -0.1225,  ...,  0.3097, -0.7325,  0.3468],
#          [ 0.6926, -0.4992, -0.0161,  ...,  0.1480, -0.2440,  0.5284]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.1333, -0.1520, -0.5079,  ...,  0.1124, -0.2851,  0.1523],
#          [ 0.1463,  0.0390, -0.0016,  ...,  0.1888, -0.6017,  0.4084],
#          [ 0.4039,  0.1939,  0.2012,  ...,  0.6389, -0.9818, -0.3404],
#          ...,
#          [-0.1639, -1.3000, -0.4116,  ...,  0.0795, -0.6730, -0.6754],
#          [ 0.1954, -0.9903, -0.8240,  ...,  0.3209, -0.6370, -0.2176],
#          [ 1.0568, -0.4607, -0.2710,  ...,  0.2927, -0.2258,  0.3896]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.2188,  0.1704, -0.3597,  ..., -0.0066,  0.0817,  0.2762],
#          [-0.0931, -0.3944, -0.3717,  ...,  0.9438, -0.1165, -0.6112],
#          [ 0.4775, -0.3140, -0.0541,  ...,  0.7510, -0.0326,  0.2622],
#          ...,
#          [ 0.2713, -0.6001, -0.5756,  ..., -0.2915, -0.3559, -0.5089],
#          [ 0.4222, -0.9761, -0.9425,  ...,  0.3852, -0.3556, -0.4322],
#          [ 0.7551, -0.6424, -0.9205,  ...,  0.2313, -0.5761,  0.4775]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1156,  0.1565, -0.3174,  ...,  0.2750, -0.3842,  0.1569],
#          [-0.2807,  0.0475, -0.0116,  ..., -0.4800, -0.3432, -0.1715],
#          [ 0.3539,  0.0681, -0.0877,  ..., -0.1301,  0.4568, -0.2381],
#          ...,
#          [-0.2787,  0.0856, -0.1611,  ...,  0.8019, -0.7588, -0.5579],
#          [-0.1479, -0.0292,  0.0175,  ...,  0.9023, -0.5501, -0.1577],
#          [ 0.7881, -0.5376, -0.0121,  ...,  1.2485, -0.6135,  0.3354]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.3496, -0.4191,  0.1702,  ...,  0.0831, -0.1034, -0.0020],
#          [-0.7998, -0.5504, -0.1231,  ..., -0.2085,  0.2780, -0.0683],
#          [-0.8269, -0.7252, -0.1034,  ..., -0.1517,  0.5639,  0.1000],
#          ...,
#          [ 0.2486, -0.1840,  0.0235,  ..., -0.1645,  0.2530, -0.1258],
#          [ 0.0523, -0.6069, -0.0336,  ...,  0.0941,  0.3626,  0.1455],
#          [ 1.2233, -1.2535, -0.0156,  ...,  0.9387,  0.3385,  0.2328]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.2349,  0.4681, -0.0989,  ...,  0.1108, -0.2418,  0.0014],
#          [ 0.4919, -0.2225,  0.1894,  ..., -0.2463,  0.5698,  0.3943],
#          [ 0.0604, -1.0796, -0.2112,  ..., -0.1562, -0.0254, -0.2654],
#          ...,
#          [ 0.0600,  0.2002,  0.2408,  ...,  0.2803, -0.8209, -0.0972],
#          [-0.2994, -0.1020, -0.1225,  ...,  0.3097, -0.7325,  0.3468],
#          [ 0.6926, -0.4992, -0.0161,  ...,  0.1480, -0.2440,  0.5284]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.1333, -0.1520, -0.5079,  ...,  0.1124, -0.2851,  0.1523],
#          [ 0.1463,  0.0390, -0.0016,  ...,  0.1888, -0.6017,  0.4084],
#          [ 0.4039,  0.1939,  0.2012,  ...,  0.6389, -0.9818, -0.3404],
#          ...,
#          [-0.1639, -1.3000, -0.4116,  ...,  0.0795, -0.6730, -0.6754],
#          [ 0.1954, -0.9903, -0.8240,  ...,  0.3209, -0.6370, -0.2176],
#          [ 1.0568, -0.4607, -0.2710,  ...,  0.2927, -0.2258,  0.3896]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.008354421705007553
# The value of j is: 85
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.2009, -0.3563, -0.1471,  ..., -0.0820, -0.0978, -0.0462],
#          [ 0.0270, -0.2576, -0.0071,  ...,  0.1628,  0.8085,  0.3438],
#          [ 0.4399, -0.6525, -0.3905,  ..., -0.0229, -0.3147, -0.6519],
#          ...,
#          [ 0.5157, -0.1476,  0.1186,  ..., -0.2192, -0.2094, -0.2046],
#          [ 0.0445, -0.5881,  0.0685,  ...,  0.1782,  0.0041, -0.3564],
#          [ 1.2912, -1.1511, -0.1292,  ...,  0.1766, -0.2172,  0.3197]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.2009, -0.3563, -0.1471,  ..., -0.0820, -0.0978, -0.0462],
#          [ 0.0270, -0.2576, -0.0071,  ...,  0.1628,  0.8085,  0.3438],
#          [ 0.4399, -0.6525, -0.3905,  ..., -0.0229, -0.3147, -0.6519],
#          ...,
#          [ 0.5157, -0.1476,  0.1186,  ..., -0.2192, -0.2094, -0.2046],
#          [ 0.0445, -0.5881,  0.0685,  ...,  0.1782,  0.0041, -0.3564],
#          [ 1.2912, -1.1511, -0.1292,  ...,  0.1766, -0.2172,  0.3197]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007834827527403831
# The value of j is: 86
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0610,  0.0906,  0.0285,  ...,  0.4112, -0.3212, -0.0682],
#          [ 0.2189, -0.2230, -0.1024,  ...,  0.2256,  0.8376, -0.2428],
#          [-0.0835, -0.7778, -0.4868,  ...,  0.5599,  0.2831, -0.1450],
#          ...,
#          [ 0.2582, -0.6262,  0.5246,  ..., -0.1276, -0.6590,  0.1717],
#          [ 0.0605, -0.2888,  0.2551,  ...,  0.3975,  0.1641, -0.0150],
#          [ 0.1692, -0.6155, -0.1681,  ...,  0.6836, -0.2482,  0.7843]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.0610,  0.0906,  0.0285,  ...,  0.4112, -0.3212, -0.0682],
#          [ 0.2189, -0.2230, -0.1024,  ...,  0.2256,  0.8376, -0.2428],
#          [-0.0835, -0.7778, -0.4868,  ...,  0.5599,  0.2831, -0.1450],
#          ...,
#          [ 0.2582, -0.6262,  0.5246,  ..., -0.1276, -0.6590,  0.1717],
#          [ 0.0605, -0.2888,  0.2551,  ...,  0.3975,  0.1641, -0.0150],
#          [ 0.1692, -0.6155, -0.1681,  ...,  0.6836, -0.2482,  0.7843]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[-0.0701,  0.2508, -0.5537,  ...,  0.0143, -0.2025,  0.0347],
#          [ 0.2608,  0.2344, -0.0564,  ...,  0.1900,  0.0014, -0.2437],
#          [ 0.0693, -0.2716,  0.1157,  ...,  1.1016, -0.5667, -0.4223],
#          ...,
#          [ 0.1063, -0.4500, -0.4648,  ..., -0.0470, -0.3908, -0.2812],
#          [-0.2201, -0.4479, -0.0388,  ...,  0.3573, -0.2249,  0.5389],
#          [ 0.0811, -0.4892, -0.6029,  ..., -0.0644,  0.1028,  0.7303]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.0610,  0.0906,  0.0285,  ...,  0.4112, -0.3212, -0.0682],
#          [ 0.2189, -0.2230, -0.1024,  ...,  0.2256,  0.8376, -0.2428],
#          [-0.0835, -0.7778, -0.4868,  ...,  0.5599,  0.2831, -0.1450],
#          ...,
#          [ 0.2582, -0.6262,  0.5246,  ..., -0.1276, -0.6590,  0.1717],
#          [ 0.0605, -0.2888,  0.2551,  ...,  0.3975,  0.1641, -0.0150],
#          [ 0.1692, -0.6155, -0.1681,  ...,  0.6836, -0.2482,  0.7843]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[-0.0701,  0.2508, -0.5537,  ...,  0.0143, -0.2025,  0.0347],
#          [ 0.2608,  0.2344, -0.0564,  ...,  0.1900,  0.0014, -0.2437],
#          [ 0.0693, -0.2716,  0.1157,  ...,  1.1016, -0.5667, -0.4223],
#          ...,
#          [ 0.1063, -0.4500, -0.4648,  ..., -0.0470, -0.3908, -0.2812],
#          [-0.2201, -0.4479, -0.0388,  ...,  0.3573, -0.2249,  0.5389],
#          [ 0.0811, -0.4892, -0.6029,  ..., -0.0644,  0.1028,  0.7303]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007851759903132915
# The value of j is: 87
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.0147,  0.2971,  0.2586,  ..., -0.0247,  0.0102, -0.1664],
#          [ 0.1208,  0.4729,  0.5808,  ...,  0.2202,  0.2014,  0.1029],
#          [ 0.1246,  0.2068,  0.2343,  ...,  0.3640, -0.0724, -0.0423],
#          ...,
#          [ 0.1115,  0.6796, -0.0044,  ...,  0.5494, -0.3852, -0.1560],
#          [-0.1750, -0.0857, -0.1454,  ...,  0.6024, -0.1537,  0.0124],
#          [ 0.8721, -0.5614,  0.6249,  ...,  0.3683,  0.0765, -0.1022]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.0147,  0.2971,  0.2586,  ..., -0.0247,  0.0102, -0.1664],
#          [ 0.1208,  0.4729,  0.5808,  ...,  0.2202,  0.2014,  0.1029],
#          [ 0.1246,  0.2068,  0.2343,  ...,  0.3640, -0.0724, -0.0423],
#          ...,
#          [ 0.1115,  0.6796, -0.0044,  ...,  0.5494, -0.3852, -0.1560],
#          [-0.1750, -0.0857, -0.1454,  ...,  0.6024, -0.1537,  0.0124],
#          [ 0.8721, -0.5614,  0.6249,  ...,  0.3683,  0.0765, -0.1022]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007691540755331516
# The value of j is: 88
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.3071, -0.1192, -0.0303,  ..., -0.1234, -0.0430,  0.1241],
#          [ 0.1703, -0.2549,  0.0852,  ..., -0.0659,  0.8729,  0.3611],
#          [ 0.5222, -0.8514, -0.3841,  ..., -0.2607,  0.0633, -0.6512],
#          ...,
#          [-0.0321, -0.8368, -0.3906,  ..., -0.0891, -0.7688,  0.4686],
#          [ 0.4779, -0.4452, -0.2833,  ..., -0.3394,  0.0942, -0.2913],
#          [ 1.0489, -0.9572,  0.2652,  ...,  0.1266, -0.4465,  0.1076]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.3071, -0.1192, -0.0303,  ..., -0.1234, -0.0430,  0.1241],
#          [ 0.1703, -0.2549,  0.0852,  ..., -0.0659,  0.8729,  0.3611],
#          [ 0.5222, -0.8514, -0.3841,  ..., -0.2607,  0.0633, -0.6512],
#          ...,
#          [-0.0321, -0.8368, -0.3906,  ..., -0.0891, -0.7688,  0.4686],
#          [ 0.4779, -0.4452, -0.2833,  ..., -0.3394,  0.0942, -0.2913],
#          [ 1.0489, -0.9572,  0.2652,  ...,  0.1266, -0.4465,  0.1076]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# *******ANALYZING TEXT*******
# The value of last_hidden_state is: tensor([[[ 0.4370, -0.0407,  0.1995,  ..., -0.3850,  0.3276, -0.0323],
#          [ 0.2678, -0.1787,  0.2323,  ..., -0.3291,  0.1670,  0.0042],
#          [ 0.3205, -0.1986,  0.7148,  ..., -0.4833,  0.1777, -0.7239],
#          ...,
#          [ 0.0391, -0.9477,  0.3178,  ...,  0.5473,  0.1866, -0.1135],
#          [ 0.2383, -0.5151,  0.1343,  ...,  0.0212,  0.0104,  0.0086],
#          [ 1.3872, -1.0687, -0.1029,  ..., -0.2927,  0.2477,  0.2449]]],
#        grad_fn=<NativeLayerNormBackward0>)
# The value of output is: [tensor([[[ 0.3071, -0.1192, -0.0303,  ..., -0.1234, -0.0430,  0.1241],
#          [ 0.1703, -0.2549,  0.0852,  ..., -0.0659,  0.8729,  0.3611],
#          [ 0.5222, -0.8514, -0.3841,  ..., -0.2607,  0.0633, -0.6512],
#          ...,
#          [-0.0321, -0.8368, -0.3906,  ..., -0.0891, -0.7688,  0.4686],
#          [ 0.4779, -0.4452, -0.2833,  ..., -0.3394,  0.0942, -0.2913],
#          [ 1.0489, -0.9572,  0.2652,  ...,  0.1266, -0.4465,  0.1076]]],
#        grad_fn=<NativeLayerNormBackward0>), tensor([[[ 0.4370, -0.0407,  0.1995,  ..., -0.3850,  0.3276, -0.0323],
#          [ 0.2678, -0.1787,  0.2323,  ..., -0.3291,  0.1670,  0.0042],
#          [ 0.3205, -0.1986,  0.7148,  ..., -0.4833,  0.1777, -0.7239],
#          ...,
#          [ 0.0391, -0.9477,  0.3178,  ...,  0.5473,  0.1866, -0.1135],
#          [ 0.2383, -0.5151,  0.1343,  ...,  0.0212,  0.0104,  0.0086],
#          [ 1.3872, -1.0687, -0.1029,  ..., -0.2927,  0.2477,  0.2449]]],
#        grad_fn=<NativeLayerNormBackward0>)]
# The value of out_tensor_mean is: -0.007833849638700485

# %%
new_tensor.shape[0]
# Out:
# 89

# %%
a = torch.reshape(new_tensor, (1, new_tensor.shape[0]))
a
# Out:
# tensor([[-0.0076, -0.0077, -0.0079, -0.0078, -0.0079, -0.0078, -0.0073, -0.0083,
#          -0.0079, -0.0077, -0.0077, -0.0081, -0.0077, -0.0079, -0.0076, -0.0075,
#          -0.0077, -0.0079, -0.0079, -0.0078, -0.0078, -0.0082, -0.0076, -0.0077,
#          -0.0086, -0.0075, -0.0078, -0.0079, -0.0079, -0.0081, -0.0077, -0.0081,
#          -0.0076, -0.0083, -0.0076, -0.0081, -0.0083, -0.0074, -0.0081, -0.0077,
#          -0.0083, -0.0081, -0.0077, -0.0080, -0.0080, -0.0079, -0.0077, -0.0080,
#          -0.0084, -0.0077, -0.0082, -0.0080, -0.0076, -0.0084, -0.0079, -0.0079,
#          -0.0078, -0.0080, -0.0080, -0.0080, -0.0083, -0.0077, -0.0077, -0.0081,
#          -0.0078, -0.0081, -0.0077, -0.0078, -0.0077, -0.0082, -0.0080, -0.0079,
#          -0.0079, -0.0081, -0.0079, -0.0079, -0.0078, -0.0079, -0.0081, -0.0081,
#          -0.0078, -0.0081, -0.0077, -0.0078, -0.0084, -0.0078, -0.0079, -0.0077,
#          -0.0078]])

# %%
# for i in range(len(tensor_list)):
input_dim = a.shape[1]
hidden_dim = 89
n_layers = 1
lstm_layer = LSTM(input_dim, hidden_dim, n_layers, batch_first = False)
h_t = torch.zeros(1, 89, dtype = torch.float32)
c_t = torch.zeros(1, 89, dtype = torch.float32)
output, (h_t_new, c_t_new) = lstm_layer(a, (h_t, c_t))
softmax_layer = Softmax(dim = 1)
final_out = softmax_layer(output)
predicted_labels = (final_out.flatten() > 0.5)

# %%
true_labels = torch.as_tensor(df_sample.SEPSIS.values)

# %%
accuracy = (predicted_labels == true_labels[0:89]).sum() / len(predicted_labels)

# %%
accuracy
# Out:
# tensor(0.9888)

# %%
roc_auc_score(true_labels[0:89], predicted_labels)
# Out:
# 0.5
